# %% [markdown]
# ## 02  ESM2 Embedding Extraction

# %%
# !pip install transformers accelerate einops biopython
# Out:
# ...
#   Using cached einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached hf_xet-1.2.0-cp37-abi3-macosx_11_0_arm64.whl.metadata (4.9 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 28.7 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.1/566.1 kB 12.1 MB/s eta 0:00:00
# Using cached hf_xet-1.2.0-cp37-abi3-macosx_11_0_arm64.whl (2.7 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 29.0 MB/s eta 0:00:00
# ...
# Using cached einops-0.8.1-py3-none-any.whl (64 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 42.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 MB 31.8 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [transformers] [transformers]ub]
# ...

# %%
import os
import torch
from transformers import AutoModel, AutoTokenizer
from Bio import SeqIO
import numpy as np
from tqdm.auto import tqdm

# %% [markdown]
# ## ESM2 options
# | Model         | Params | VRAM Needed | Notes                                              |
# | ------------- | ------ | ----------- | -------------------------------------------------- |
# | **ESM2-650M** | ~650M  | 14–20 GB    | Best for your 4090, safe for Colab               |
# | **ESM2-1.3B** | 1.3B   | 24–28 GB    | borderline                                         |
# | **ESM2-3B**   | 3B     | 40–60 GB    | Requires A100 40GB, safe for Colab Pro A100 only |
